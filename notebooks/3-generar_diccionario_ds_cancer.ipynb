# %%
import pandas as pd

# Cargar el dataset
file_path = '../data/processed/df_cancer_prostata_processed.csv'
data_cleaned = pd.read_csv(file_path)


# Mostrar las primeras filas y un resumen de los datos
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 60 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RELIGION1                                   2644 non-null   object
#  1   ETNIA                                       2644 non-null   object
#  2   ZONA_VIVIENDA                               2644 non-null   object
#  3   COMUNA                                      2644 non-null   object
#  4   REGION                                      2644 non-null   object
#  5   SSREFERENCIA                                2644 non-null   object
#  6   RECINTO_PROCEDE                             2644 non-null   object
#  7   ESTABLE_DESTINO                             2644 non-null   object
#  8   ACT_LABORAL                                 2644 non-null   object
#  9   ACT_EMPRESA                                 2644 non-null   object
#  10  SITUACION_LABORAL                           2644 non-null   object
#  11  ULT_CURSO_APROBADO                          2644 non-null   object
#  12  CANCER_PREVIO_1                             2644 non-null   object
#  13  CANCER_PREVIO_2                             2644 non-null   object
#  14  PARENTESCO_1                                2644 non-null   object
#  15  CANCER_PARENTESCO_1                         2644 non-null   object
#  16  PARENTESCO_2                                2644 non-null   object
#  17  CANCER_PARENTESCO_2                         2644 non-null   object
#  18  PARENTESCO_3                                2644 non-null   object
#  19  CANCER_PARENTESCO_3                         2644 non-null   object
#  20  TIPO_TUMOR                                  2644 non-null   object
#  21  COD_TOPOLOGIA                               2644 non-null   int64
#  22  NOM_TOPOLOGIA                               2644 non-null   object
#  23  COD_DET_TOPOLOGIA                           2644 non-null   object
#  24  NOM_DETALLE_TOPO                            2644 non-null   object
#  25  COD_CIE10                                   2644 non-null   object
#  26  MORFO_COMPLETA                              2644 non-null   object
#  27  NOM_COMPORTAMIENTO                          2644 non-null   object
#  28  EXTENSION_NOM                               2644 non-null   object
#  29  LATERALIDAD_NOM                             2644 non-null   object
#  30  GRADO_DIFERENCIACION                        2644 non-null   object
#  31  BASE_DIAGNOSTICA                            2644 non-null   object
#  32  TUMOR                                       2644 non-null   object
#  33  GRAVEDAD                                    2644 non-null   object
#  34  POBLACION                                   2644 non-null   object
#  35  ETAPA_CLINICA                               2644 non-null   object
#  36  SUBTIPO                                     2644 non-null   int64
#  37  ESTADO_ACTUAL_TTO                           2644 non-null   object
#  38  CLASE_DE_CASO                               2644 non-null   object
#  39  FUENTE_1                                    2644 non-null   object
#  40  ESTADO                                      2644 non-null   object
#  41  INTENCION_TRATA                             2644 non-null   object
#  42  RESPUESTA_TRATA                             2644 non-null   object
#  43  EDAD                                        2644 non-null   float64
#  44  TIPO_TERAPIA_1                              2644 non-null   object
#  45  TIPO_TERAPIA_2                              2644 non-null   object
#  46  TIPO_TRATAMIENTO_1                          2644 non-null   object
#  47  TIPO_TRATAMIENTO_2                          2644 non-null   object
#  48  Tipo_Tumor                                  2644 non-null   object
#  49  T                                           2644 non-null   object
#  50  N                                           2644 non-null   object
#  51  M                                           2644 non-null   object
#  52  DIAS_HASTA_INICIO_TRATAMIENTO               2644 non-null   int64
#  53  SOBREVIVE                                   2644 non-null   float64
#  54  DIAS_DESDE_NACIMIENTO_A_DIAGNO              2644 non-null   int64
#  55  DIAS_DESDE_NACIMIENTO_A_INGRESO             2644 non-null   int64
#  56  DIAS_DESDE_NACIMIENTO_A_COMITE              2644 non-null   float64
#  57  DIAS_DESDE_NACIMIENTO_TOM_MUESTRA           2644 non-null   float64
#  58  DIAS_DESDE_NACIMIENTO_TRATAMIENTO_1_INICIO  2644 non-null   int64
#  59  DIAS_DESDE_NACIMIENTO_TRATAMIENTO_1_FIN     2644 non-null   float64
# dtypes: float64(5), int64(6), object(49)
# memory usage: 1.2+ MB

# %%
# 1. Obtener información sobre las columnas
diccionario_columnas = {}

for columna in data_cleaned.columns:
    tipo_variable = str(data_cleaned[columna].dtype)  # Convertir a cadena de texto
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(data_cleaned[columna]):
        tipo_variable += " (Numérica)"
    else:
        tipo_variable += " (Categórica)"
    
    # Resumen del contenido
    resumen_contenido = data_cleaned[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar al diccionario
    diccionario_columnas[columna] = {
        "Tipo": tipo_variable,
        "Resumen": resumen_contenido
    }

# %%
# 2. Obtener información sobre las columnas
diccionario_columnas_numericas = {}
diccionario_columnas_categoricas = {}

for columna in data_cleaned.columns:
    tipo_variable = str(data_cleaned[columna].dtype)  # Convertir a cadena de texto
    
    # Resumen del contenido
    resumen_contenido = data_cleaned[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(data_cleaned[columna]):
        tipo_variable += " (Numérica)"
        # Agregar al diccionario de columnas numéricas
        diccionario_columnas_numericas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }
    else:
        tipo_variable += " (Categórica)"
        # Agregar al diccionario de columnas categóricas
        diccionario_columnas_categoricas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }

# 3. Exportar el diccionario a Excel
ruta_excel = "../docs/DiccionarioDS_Cancer.xlsx"   # Ruta donde se guardará el archivo Excel
with pd.ExcelWriter(ruta_excel) as writer:
    # Hoja para columnas numéricas
    df_numericas = pd.DataFrame()
    for columna, info in diccionario_columnas_numericas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_numericas = pd.concat([df_numericas, resumen_transpuesto], ignore_index=True)
    df_numericas.to_excel(writer, index=False, sheet_name="Columnas Numéricas")
    
    # Hoja para columnas categóricas
    df_categoricas = pd.DataFrame()
    for columna, info in diccionario_columnas_categoricas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_categoricas = pd.concat([df_categoricas, resumen_transpuesto], ignore_index=True)
    df_categoricas.to_excel(writer, index=False, sheet_name="Columnas Categóricas")

print("El diccionario de columnas se ha exportado a Excel exitosamente.")
# Out:
# El diccionario de columnas se ha exportado a Excel exitosamente.
