# %%
import pandas as pd

# Cargar el dataset
file_path = '../data/processed/df_cancer_prostata_processed.csv'
data_cleaned = pd.read_csv(file_path)


# Mostrar las primeras filas y un resumen de los datos
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 70 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   IDPACIENTE                     2644 non-null   int64
#  1   IDTUMOR                        2644 non-null   int64
#  2   SEXO                           2644 non-null   object
#  3   FEC_NACIMIENTO                 2644 non-null   object
#  4   PREVISION                      2644 non-null   object
#  5   RELIGION1                      2644 non-null   object
#  6   ETNIA                          2644 non-null   object
#  7   ZONA_VIVIENDA                  2644 non-null   object
#  8   COMUNA                         2644 non-null   object
#  9   REGION                         2644 non-null   object
#  10  SSREFERENCIA                   2644 non-null   object
#  11  RECINTO_PROCEDE                2644 non-null   object
#  12  ESTABLE_DESTINO                2644 non-null   object
#  13  ACT_LABORAL                    2644 non-null   object
#  14  ACT_EMPRESA                    2644 non-null   object
#  15  SITUACION_LABORAL              2644 non-null   object
#  16  ULT_CURSO_APROBADO             2644 non-null   object
#  17  CANCER_PREVIO_1                2644 non-null   object
#  18  CANCER_PREVIO_2                2644 non-null   object
#  19  PARENTESCO_1                   2644 non-null   object
#  20  CANCER_PARENTESCO_1            2644 non-null   object
#  21  PARENTESCO_2                   2644 non-null   object
#  22  CANCER_PARENTESCO_2            2644 non-null   object
#  23  PARENTESCO_3                   2644 non-null   object
#  24  CANCER_PARENTESCO_3            2644 non-null   object
#  25  FECHA_COMITE                   1928 non-null   object
#  26  FEC_INGRESO_CASO               2644 non-null   object
#  27  FEC_DIAGNO                     2644 non-null   object
#  28  FEC_TOM_MUESTRA                2643 non-null   object
#  29  TIPO_TUMOR                     2644 non-null   object
#  30  COD_TOPOLOGIA                  2644 non-null   int64
#  31  NOM_TOPOLOGIA                  2644 non-null   object
#  32  COD_DET_TOPOLOGIA              2644 non-null   object
#  33  NOM_DETALLE_TOPO               2644 non-null   object
#  34  COD_CIE10                      2644 non-null   object
#  35  MORFO_COMPLETA                 2644 non-null   object
#  36  NOM_COMPORTAMIENTO             2644 non-null   object
#  37  EXTENSION_NOM                  2644 non-null   object
#  38  LATERALIDAD_NOM                2644 non-null   object
#  39  GRADO_DIFERENCIACION           2644 non-null   object
#  40  BASE_DIAGNOSTICA               2644 non-null   object
#  41  TUMOR                          2644 non-null   object
#  42  GRAVEDAD                       2644 non-null   object
#  43  POBLACION                      2644 non-null   object
#  44  ETAPA_CLINICA                  2287 non-null   object
#  45  SUBTIPO                        2315 non-null   float64
#  46  ESTADO_ACTUAL                  2644 non-null   object
#  47  ESTADO_ACTUAL_TTO              2644 non-null   object
#  48  ULTIMO_CONTACTO                2644 non-null   object
#  49  ESTADO_RECH                    2644 non-null   object
#  50  CLASE_DE_CASO                  2644 non-null   object
#  51  FUENTE_1                       2378 non-null   object
#  52  ESTADO                         2644 non-null   object
#  53  INTENCION_TRATA                2644 non-null   object
#  54  RESPUESTA_TRATA                2644 non-null   object
#  55  OBSERVACIONES                  2644 non-null   object
#  56  TIPO_TERAPIA_1                 2644 non-null   object
#  57  TIPO_TERAPIA_2                 920 non-null    object
#  58  FECHA_INICIO_1                 2644 non-null   object
#  59  FECHA_INICIO_2                 899 non-null    object
#  60  FECHA_TERMINO_1                2583 non-null   object
#  61  FECHA_TERMINO_2                790 non-null    object
#  62  TIPO_TRATAMIENTO_1             2644 non-null   object
#  63  TIPO_TRATAMIENTO_2             920 non-null    object
#  64  Tipo_Tumor                     2251 non-null   object
#  65  T                              2214 non-null   object
#  66  N                              2214 non-null   object
#  67  M                              2214 non-null   object
#  68  DIAS_HASTA_INICIO_TRATAMIENTO  2644 non-null   int64
#  69  SOBREVIVE                      2644 non-null   float64
# dtypes: float64(2), int64(4), object(64)
# memory usage: 1.4+ MB

# %%
# 1. Obtener información sobre las columnas
diccionario_columnas = {}

for columna in data_cleaned.columns:
    tipo_variable = str(data_cleaned[columna].dtype)  # Convertir a cadena de texto
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(data_cleaned[columna]):
        tipo_variable += " (Numérica)"
    else:
        tipo_variable += " (Categórica)"
    
    # Resumen del contenido
    resumen_contenido = data_cleaned[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar al diccionario
    diccionario_columnas[columna] = {
        "Tipo": tipo_variable,
        "Resumen": resumen_contenido
    }

# %%
# 2. Obtener información sobre las columnas
diccionario_columnas_numericas = {}
diccionario_columnas_categoricas = {}

for columna in data_cleaned.columns:
    tipo_variable = str(data_cleaned[columna].dtype)  # Convertir a cadena de texto
    
    # Resumen del contenido
    resumen_contenido = data_cleaned[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(data_cleaned[columna]):
        tipo_variable += " (Numérica)"
        # Agregar al diccionario de columnas numéricas
        diccionario_columnas_numericas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }
    else:
        tipo_variable += " (Categórica)"
        # Agregar al diccionario de columnas categóricas
        diccionario_columnas_categoricas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }

# 3. Exportar el diccionario a Excel
ruta_excel = "../docs/DiccionarioDS_Cancer.xlsx"   # Ruta donde se guardará el archivo Excel
with pd.ExcelWriter(ruta_excel) as writer:
    # Hoja para columnas numéricas
    df_numericas = pd.DataFrame()
    for columna, info in diccionario_columnas_numericas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_numericas = pd.concat([df_numericas, resumen_transpuesto], ignore_index=True)
    df_numericas.to_excel(writer, index=False, sheet_name="Columnas Numéricas")
    
    # Hoja para columnas categóricas
    df_categoricas = pd.DataFrame()
    for columna, info in diccionario_columnas_categoricas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_categoricas = pd.concat([df_categoricas, resumen_transpuesto], ignore_index=True)
    df_categoricas.to_excel(writer, index=False, sheet_name="Columnas Categóricas")

print("El diccionario de columnas se ha exportado a Excel exitosamente.")
# Out:
# El diccionario de columnas se ha exportado a Excel exitosamente.
