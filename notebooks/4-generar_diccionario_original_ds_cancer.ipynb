# %%
import pandas as pd

# Cargar el dataset

df = pd.read_excel("../data/raw/cancer_hbv.xlsx", engine='openpyxl')

# Mostrar las primeras filas y un resumen de los datos
df.describe(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23553 entries, 0 to 23552
# Data columns (total 100 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   IDPACIENTE                23553 non-null  int64
#  1   IDTUMOR                   23553 non-null  int64
#  2   SEXO                      23553 non-null  object
#  3   FEC_NACIMIENTO            23553 non-null  object
#  4   EDAD                      23553 non-null  object
#  5   PREVISION                 23553 non-null  object
#  6   COD_RELIGION              23522 non-null  float64
#  7   RELIGION1                 23495 non-null  object
#  8   COD_ETNIA                 23525 non-null  float64
#  9   ETNIA                     23525 non-null  object
#  10  ETNIA_APELLIDO            21728 non-null  object
#  11  DIRECCION                 23086 non-null  object
#  12  NUM_DOMICILIO             17266 non-null  object
#  13  DEPTO_DOMICILIO           441 non-null    object
#  14  LOCALIDAD_DOMICILIO       9476 non-null   object
#  15  COD_ZONA                  23460 non-null  float64
#  16  ZONA_VIVIENDA             23460 non-null  object
#  17  COD_COMUNA                23553 non-null  int64
#  18  COMUNA                    23552 non-null  object
#  19  COD_REGION                23553 non-null  int64
#  20  REGION                    23553 non-null  object
#  21  COD_SSREFERENCIA          23541 non-null  float64
#  22  SSREFERENCIA              23532 non-null  object
#  23  COD_RECINTO_PROCEDE       23525 non-null  object
#  24  RECINTO_PROCEDE           23511 non-null  object
#  25  COD_ESTABLE_DESTINO       22045 non-null  object
#  26  ESTABLE_DESTINO           22037 non-null  object
#  27  COD_ACT_LABORAL           23540 non-null  float64
#  28  ACT_LABORAL               23530 non-null  object
#  29  COD_ACT_EMPRESA           23530 non-null  float64
#  30  ACT_EMPRESA               23522 non-null  object
#  31  COD_SIT_LABORAL           23459 non-null  float64
#  32  SITUACION_LABORAL         23451 non-null  object
#  33  ANHOSESTUDIO              3860 non-null   float64
#  34  COD_ULT_CURSO             23465 non-null  float64
#  35  ULT_CURSO_APROBADO        23465 non-null  object
#  36  CANCER_PREVIO1            23456 non-null  object
#  37  FECHA1                    778 non-null    object
#  38  CANCER_PREVIO2            22066 non-null  object
#  39  FECHA2                    55 non-null     object
#  40  PARENTESCO1               23495 non-null  object
#  41  CANCER_PARENTESCO1        22204 non-null  object
#  42  PARENTESCO2               22166 non-null  object
#  43  CANCER_PARENTESCO2        22101 non-null  object
#  44  PARENTESCO3               22089 non-null  object
#  45  CANCER_PARENTESCO3        22069 non-null  object
#  46  ID_COMITE                 23553 non-null  object
#  47  DESCRIPCION_COMITE        23553 non-null  object
#  48  FECHA_COMITE              15498 non-null  object
#  49  FEC_INGRESO_CASO          23547 non-null  object
#  50  FEC_DIAGNO                23551 non-null  object
#  51  INTERVALO_INGRESO_DIAGNO  23547 non-null  float64
#  52  FEC_TOM_MUESTRA           23548 non-null  object
#  53  TIPO_TUMOR                23546 non-null  object
#  54  COD_TOPOLOGIA             23553 non-null  int64
#  55  NOM_TOPOLOGIA             23553 non-null  object
#  56  COD_DET_TOPOLOGIA         23546 non-null  object
#  57  NOM_DETALLE_TOPO          23545 non-null  object
#  58  COD_CIE10                 23548 non-null  object
#  59  COD_MORFO                 23549 non-null  float64
#  60  MORFO_COMPLETA            23539 non-null  object
#  61  COD_COMPORTAMIENTO        23542 non-null  float64
#  62  NOM_COMPORTAMIENTO        23542 non-null  object
#  63  COD_EXTENSION             23522 non-null  float64
#  64  EXTENSION_NOM             23522 non-null  object
#  65  COD_LATERALIDAD           23514 non-null  float64
#  66  LATERALIDAD_NOM           23514 non-null  object
#  67  COD_GRADO                 23538 non-null  float64
#  68  GRADO_DIFERENCIACION      23538 non-null  object
#  69  COD_BASE                  23547 non-null  float64
#  70  BASE_DIAGNOSTICA          23547 non-null  object
#  71  TUMOR                     23553 non-null  object
#  72  GRAVEDAD                  23553 non-null  object
#  73  POBLACION                 23553 non-null  object
#  74  LINFOMA                   917 non-null    object
#  75  FIGO                      1867 non-null   object
#  76  FIGO_LETRA                1431 non-null   object
#  77  ETAPA_CLINICA             16550 non-null  object
#  78  ETAPA_LETRA               6004 non-null   object
#  79  TNM                       16664 non-null  object
#  80  SUBTIPO                   21489 non-null  object
#  81  RECEPTORES                4744 non-null   object
#  82  ESTADO_ACTUAL             23549 non-null  object
#  83  ESTADO_ACTUAL_TTO         22610 non-null  object
#  84  ULTIMO_CONTACTO           23547 non-null  object
#  85  FECHA_FALLECIMIENTO       8325 non-null   object
#  86  CAUSAFALLECIMIENTO        8251 non-null   object
#  87  ESTADO_RECH               23553 non-null  object
#  88  CLASEDECASO               23551 non-null  object
#  89  FUENTE1                   20933 non-null  object
#  90  FUENTE2                   7533 non-null   object
#  91  FUENTE3                   1763 non-null   object
#  92  ESTADO                    23553 non-null  object
#  93  INTENCION_TRATA           21800 non-null  object
#  94  RESPUESTA_TRATA           21782 non-null  object
#  95  TIPOTERAPIA               23553 non-null  object
#  96  FECHAINICIO               23553 non-null  object
#  97  FECHATERMINO              23553 non-null  object
#  98  TIPO                      23553 non-null  object
#  99  OBSERVACIONES             22543 non-null  object
# dtypes: float64(16), int64(5), object(79)
# memory usage: 18.0+ MB
# (         IDPACIENTE       IDTUMOR  COD_RELIGION     COD_ETNIA      COD_ZONA  \
#  count  23553.000000  23553.000000  23522.000000  23525.000000  23460.000000
#  mean   16467.194413  15337.091920     10.941161      1.269203      1.245951
#  std     8688.256036   7847.515208      2.583470      3.414166      0.554266
#  min        9.000000      7.000000      0.000000      0.000000      1.000000
#  25%     9583.000000   8979.000000     12.000000      0.000000      1.000000
#  50%    16006.000000  15459.000000     12.000000      0.000000      1.000000
#  75%    23175.000000  21795.000000     12.000000      0.000000      1.000000
#  max    38148.000000  34137.000000     12.000000     12.000000      9.000000
#
#           COD_COMUNA    COD_REGION  COD_SSREFERENCIA  COD_ACT_LABORAL  \
#  count  23553.000000  23553.000000      23541.000000     23540.000000
#  mean   12284.457267     12.145204         23.176925        76.123407
#  std     2161.802925      2.174802          3.382260        39.999834
#  min        0.000000      4.000000          0.000000         0.000000
#  25%    10104.000000     10.000000         22.000000        99.000000
#  50%    14101.000000     14.000000         22.000000        99.000000
#  75%    14104.000000     14.000000         24.000000        99.000000
#  max    14204.000000     14.000000         34.000000        99.000000
#
#         COD_ACT_EMPRESA  ...  ANHOSESTUDIO  COD_ULT_CURSO  \
#  count     23530.000000  ...   3860.000000   23465.000000
#  mean          8.890013  ...      9.768653       7.898913
#  std           3.128398  ...      4.656437       2.296065
#  min           0.000000  ...      0.000000       1.000000
#  25%          10.000000  ...      6.000000       9.000000
#  50%          10.000000  ...     11.000000       9.000000
#  75%          10.000000  ...     12.000000       9.000000
#  max          99.000000  ...     24.000000       9.000000
#
#         INTERVALO_INGRESO_DIAGNO  COD_TOPOLOGIA     COD_MORFO  \
#  count              23547.000000   23553.000000  23549.000000
#  mean                  75.368327      46.303868   8437.162979
#  std                  270.999045      18.372297    535.454498
#  min                -6791.000000       1.000000   8000.000000
#  25%                  -18.000000      34.000000   8090.000000
#  50%                    6.000000      50.000000   8211.000000
#  75%                  102.000000      61.000000   8500.000000
#  max                 4191.000000      81.000000   9992.000000
#
#         COD_COMPORTAMIENTO  COD_EXTENSION  COD_LATERALIDAD     COD_GRADO  \
#  count        23542.000000   23522.000000     23514.000000  23538.000000
#  mean             2.895039       2.911530         3.393893      5.021880
#  std              0.413631       3.138695         1.363125      3.287603
#  min              0.000000       0.000000         1.000000      1.000000
#  25%              3.000000       1.000000         2.000000      2.000000
#  50%              3.000000       2.000000         4.000000      3.000000
#  75%              3.000000       3.000000         4.000000      9.000000
#  max              3.000000      10.000000         9.000000      9.000000
#
#             COD_BASE
#  count  23547.000000
#  mean       6.465834
#  std        1.404227
#  min        1.000000
#  25%        7.000000
#  50%        7.000000
#  75%        7.000000
#  max        9.000000
#
#  [8 rows x 21 columns],
#  None)

# %%
df.columns
# Out:
# Index(['IDPACIENTE', 'IDTUMOR', 'SEXO', 'FEC_NACIMIENTO', 'EDAD', 'PREVISION',
#        'COD_RELIGION', 'RELIGION1', 'COD_ETNIA', 'ETNIA', 'ETNIA_APELLIDO',
#        'DIRECCION', 'NUM_DOMICILIO', 'DEPTO_DOMICILIO', 'LOCALIDAD_DOMICILIO',
#        'COD_ZONA', 'ZONA_VIVIENDA', 'COD_COMUNA', 'COMUNA', 'COD_REGION',
#        'REGION', 'COD_SSREFERENCIA', 'SSREFERENCIA', 'COD_RECINTO_PROCEDE',
#        'RECINTO_PROCEDE', 'COD_ESTABLE_DESTINO', 'ESTABLE_DESTINO',
#        'COD_ACT_LABORAL', 'ACT_LABORAL', 'COD_ACT_EMPRESA', 'ACT_EMPRESA',
#        'COD_SIT_LABORAL', 'SITUACION_LABORAL', 'ANHOSESTUDIO', 'COD_ULT_CURSO',
#        'ULT_CURSO_APROBADO', 'CANCER_PREVIO1', 'FECHA1', 'CANCER_PREVIO2',
#        'FECHA2', 'PARENTESCO1', 'CANCER_PARENTESCO1', 'PARENTESCO2',
#        'CANCER_PARENTESCO2', 'PARENTESCO3', 'CANCER_PARENTESCO3', 'ID_COMITE',
#        'DESCRIPCION_COMITE', 'FECHA_COMITE', 'FEC_INGRESO_CASO', 'FEC_DIAGNO',
#        'INTERVALO_INGRESO_DIAGNO', 'FEC_TOM_MUESTRA', 'TIPO_TUMOR',
#        'COD_TOPOLOGIA', 'NOM_TOPOLOGIA', 'COD_DET_TOPOLOGIA',
#        'NOM_DETALLE_TOPO', 'COD_CIE10', 'COD_MORFO', 'MORFO_COMPLETA',
#        'COD_COMPORTAMIENTO', 'NOM_COMPORTAMIENTO', 'COD_EXTENSION',
#        'EXTENSION_NOM', 'COD_LATERALIDAD', 'LATERALIDAD_NOM', 'COD_GRADO',
#        'GRADO_DIFERENCIACION', 'COD_BASE', 'BASE_DIAGNOSTICA', 'TUMOR',
#        'GRAVEDAD', 'POBLACION', 'LINFOMA', 'FIGO', 'FIGO_LETRA',
#        'ETAPA_CLINICA', 'ETAPA_LETRA', 'TNM', 'SUBTIPO', 'RECEPTORES',
#        'ESTADO_ACTUAL', 'ESTADO_ACTUAL_TTO', 'ULTIMO_CONTACTO',
#        'FECHA_FALLECIMIENTO', 'CAUSAFALLECIMIENTO', 'ESTADO_RECH',
#        'CLASEDECASO', 'FUENTE1', 'FUENTE2', 'FUENTE3', 'ESTADO',
#        'INTENCION_TRATA', 'RESPUESTA_TRATA', 'TIPOTERAPIA', 'FECHAINICIO',
#        'FECHATERMINO', 'TIPO', 'OBSERVACIONES'],
#       dtype='object')

# %%
df.describe()
# Out:
#          IDPACIENTE       IDTUMOR  COD_RELIGION     COD_ETNIA      COD_ZONA  \
# count  23553.000000  23553.000000  23522.000000  23525.000000  23460.000000
# mean   16467.194413  15337.091920     10.941161      1.269203      1.245951
# std     8688.256036   7847.515208      2.583470      3.414166      0.554266
# min        9.000000      7.000000      0.000000      0.000000      1.000000
# 25%     9583.000000   8979.000000     12.000000      0.000000      1.000000
# 50%    16006.000000  15459.000000     12.000000      0.000000      1.000000
# 75%    23175.000000  21795.000000     12.000000      0.000000      1.000000
# max    38148.000000  34137.000000     12.000000     12.000000      9.000000
#
#          COD_COMUNA    COD_REGION  COD_SSREFERENCIA  COD_ACT_LABORAL  \
# count  23553.000000  23553.000000      23541.000000     23540.000000
# mean   12284.457267     12.145204         23.176925        76.123407
# std     2161.802925      2.174802          3.382260        39.999834
# min        0.000000      4.000000          0.000000         0.000000
# 25%    10104.000000     10.000000         22.000000        99.000000
# 50%    14101.000000     14.000000         22.000000        99.000000
# 75%    14104.000000     14.000000         24.000000        99.000000
# max    14204.000000     14.000000         34.000000        99.000000
#
#        COD_ACT_EMPRESA  ...  ANHOSESTUDIO  COD_ULT_CURSO  \
# count     23530.000000  ...   3860.000000   23465.000000
# mean          8.890013  ...      9.768653       7.898913
# std           3.128398  ...      4.656437       2.296065
# min           0.000000  ...      0.000000       1.000000
# 25%          10.000000  ...      6.000000       9.000000
# 50%          10.000000  ...     11.000000       9.000000
# 75%          10.000000  ...     12.000000       9.000000
# max          99.000000  ...     24.000000       9.000000
#
#        INTERVALO_INGRESO_DIAGNO  COD_TOPOLOGIA     COD_MORFO  \
# count              23547.000000   23553.000000  23549.000000
# mean                  75.368327      46.303868   8437.162979
# std                  270.999045      18.372297    535.454498
# min                -6791.000000       1.000000   8000.000000
# 25%                  -18.000000      34.000000   8090.000000
# 50%                    6.000000      50.000000   8211.000000
# 75%                  102.000000      61.000000   8500.000000
# max                 4191.000000      81.000000   9992.000000
#
#        COD_COMPORTAMIENTO  COD_EXTENSION  COD_LATERALIDAD     COD_GRADO  \
# count        23542.000000   23522.000000     23514.000000  23538.000000
# mean             2.895039       2.911530         3.393893      5.021880
# std              0.413631       3.138695         1.363125      3.287603
# min              0.000000       0.000000         1.000000      1.000000
# 25%              3.000000       1.000000         2.000000      2.000000
# 50%              3.000000       2.000000         4.000000      3.000000
# 75%              3.000000       3.000000         4.000000      9.000000
# max              3.000000      10.000000         9.000000      9.000000
#
#            COD_BASE
# count  23547.000000
# mean       6.465834
# std        1.404227
# min        1.000000
# 25%        7.000000
# 50%        7.000000
# 75%        7.000000
# max        9.000000
#
# [8 rows x 21 columns]

# %%
# 1. Obtener información sobre las columnas
diccionario_columnas = {}

for columna in df.columns:
    tipo_variable = str(df[columna].dtype)  # Convertir a cadena de texto
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(df[columna]):
        tipo_variable += " (Numérica)"
    else:
        tipo_variable += " (Categórica)"
    
    # Resumen del contenido
    if pd.api.types.is_datetime64_any_dtype(df[columna]):
        resumen_contenido = df[columna].describe(datetime_is_numeric=True).reset_index().rename(columns={'index': 'Descripción'})
    else:
        resumen_contenido = df[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar al diccionario
    diccionario_columnas[columna] = {
        "Tipo": tipo_variable,
        "Resumen": resumen_contenido
    }

# %%
# Agregar la impresión del diccionario_columnas aquí
print(diccionario_columnas)
# Out:
# {'IDPACIENTE': {'Tipo': 'int64 (Numérica)', 'Resumen':   Descripción    IDPACIENTE
# 0       count  23553.000000
# 1        mean  16467.194413
# 2         std   8688.256036
# 3         min      9.000000
# 4         25%   9583.000000
# 5         50%  16006.000000
# 6         75%  23175.000000
# 7         max  38148.000000}, 'IDTUMOR': {'Tipo': 'int64 (Numérica)', 'Resumen':   Descripción       IDTUMOR
# 0       count  23553.000000
# 1        mean  15337.091920
# 2         std   7847.515208
# 3         min      7.000000
# 4         25%   8979.000000
# 5         50%  15459.000000
# 6         75%  21795.000000
# 7         max  34137.000000}, 'SEXO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción   SEXO
# 0       count  23553
# 1      unique      3
# 2         top      F
# 3        freq  13242}, 'FEC_NACIMIENTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FEC_NACIMIENTO
# 0       count          23553
# 1      unique          13930
# 2         top     01-01-1947
# 3        freq             10}, 'EDAD': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción                     EDAD
# 0       count                    23553
# 1      unique                    14699
# 2         top  73 AÑOS 8 MESES 23 DÍAS
# 3        freq                        9}, 'PREVISION': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción PREVISION
# 0       count     23553
# 1      unique         8
# 2         top  FONASA B
# 3        freq     14357}, 'COD_RELIGION': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_RELIGION
# 0       count  23522.000000
# 1        mean     10.941161
# 2         std      2.583470
# 3         min      0.000000
# 4         25%     12.000000
# 5         50%     12.000000
# 6         75%     12.000000
# 7         max     12.000000}, 'RELIGION1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción    RELIGION1
# 0       count        23495
# 1      unique           11
# 2         top  NO RESPONDE
# 3        freq        18529}, 'COD_ETNIA': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción     COD_ETNIA
# 0       count  23525.000000
# 1        mean      1.269203
# 2         std      3.414166
# 3         min      0.000000
# 4         25%      0.000000
# 5         50%      0.000000
# 6         75%      0.000000
# 7         max     12.000000}, 'ETNIA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción                 ETNIA
# 0       count                 23525
# 1      unique                    10
# 2         top  Ninguna, No responde
# 3        freq                 20433}, 'ETNIA_APELLIDO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ETNIA_APELLIDO
# 0       count          21728
# 1      unique              3
# 2         top  0_AP_Indigena
# 3        freq          19260}, 'DIRECCION': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  DIRECCION
# 0       count      23086
# 1      unique      14078
# 2         top  BALMACEDA
# 3        freq         63}, 'NUM_DOMICILIO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción NUM_DOMICILIO
# 0       count         17266
# 1      unique          5008
# 2         top           S/N
# 3        freq           883}, 'DEPTO_DOMICILIO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción DEPTO_DOMICILIO
# 0       count             441
# 1      unique             206
# 2         top              14
# 3        freq              13}, 'LOCALIDAD_DOMICILIO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción LOCALIDAD_DOMICILIO
# 0       count                9476
# 1      unique                4555
# 2         top          LAS ANIMAS
# 3        freq                 311}, 'COD_ZONA': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción      COD_ZONA
# 0       count  23460.000000
# 1        mean      1.245951
# 2         std      0.554266
# 3         min      1.000000
# 4         25%      1.000000
# 5         50%      1.000000
# 6         75%      1.000000
# 7         max      9.000000}, 'ZONA_VIVIENDA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ZONA_VIVIENDA
# 0       count         23460
# 1      unique             3
# 2         top        Urbano
# 3        freq         18047}, 'COD_COMUNA': {'Tipo': 'int64 (Numérica)', 'Resumen':   Descripción    COD_COMUNA
# 0       count  23553.000000
# 1        mean  12284.457267
# 2         std   2161.802925
# 3         min      0.000000
# 4         25%  10104.000000
# 5         50%  14101.000000
# 6         75%  14104.000000
# 7         max  14204.000000}, 'COMUNA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción    COMUNA
# 0       count     23552
# 1      unique       136
# 2         top  Valdivia
# 3        freq      6212}, 'COD_REGION': {'Tipo': 'int64 (Numérica)', 'Resumen':   Descripción    COD_REGION
# 0       count  23553.000000
# 1        mean     12.145204
# 2         std      2.174802
# 3         min      4.000000
# 4         25%     10.000000
# 5         50%     14.000000
# 6         75%     14.000000
# 7         max     14.000000}, 'REGION': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción              REGION
# 0       count               23553
# 1      unique                  11
# 2         top  REGION DE LOS RIOS
# 3        freq               13338}, 'COD_SSREFERENCIA': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_SSREFERENCIA
# 0       count      23541.000000
# 1        mean         23.176925
# 2         std          3.382260
# 3         min          0.000000
# 4         25%         22.000000
# 5         50%         22.000000
# 6         75%         24.000000
# 7         max         34.000000}, 'SSREFERENCIA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción SSREFERENCIA
# 0       count        23532
# 1      unique           28
# 2         top     Valdivia
# 3        freq        11704}, 'COD_RECINTO_PROCEDE': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción COD_RECINTO_PROCEDE
# 0       count               23525
# 1      unique                 131
# 2         top              21-109
# 3        freq                3634}, 'RECINTO_PROCEDE': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción                                 RECINTO_PROCEDE
# 0       count                                           23511
# 1      unique                                             119
# 2         top  Hospital Dr. Hernan Henriquez Aravena (Temuco)
# 3        freq                                            3634}, 'COD_ESTABLE_DESTINO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción COD_ESTABLE_DESTINO
# 0       count               22045
# 1      unique                 117
# 2         top              22-100
# 3        freq               10390}, 'ESTABLE_DESTINO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción                       ESTABLE_DESTINO
# 0       count                                 22037
# 1      unique                                   110
# 2         top  Hospital Clinico Regional (Valdivia)
# 3        freq                                 10390}, 'COD_ACT_LABORAL': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_ACT_LABORAL
# 0       count     23540.000000
# 1        mean        76.123407
# 2         std        39.999834
# 3         min         0.000000
# 4         25%        99.000000
# 5         50%        99.000000
# 6         75%        99.000000
# 7         max        99.000000}, 'ACT_LABORAL': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción      ACT_LABORAL
# 0       count            23530
# 1      unique               12
# 2         top  Sin Informacion
# 3        freq            17730}, 'COD_ACT_EMPRESA': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_ACT_EMPRESA
# 0       count     23530.000000
# 1        mean         8.890013
# 2         std         3.128398
# 3         min         0.000000
# 4         25%        10.000000
# 5         50%        10.000000
# 6         75%        10.000000
# 7         max        99.000000}, 'ACT_EMPRESA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción      ACT_EMPRESA
# 0       count            23522
# 1      unique               12
# 2         top  Sin informacion
# 3        freq            16803}, 'COD_SIT_LABORAL': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_SIT_LABORAL
# 0       count     23459.000000
# 1        mean         5.773733
# 2         std         2.682625
# 3         min         0.000000
# 4         25%         3.000000
# 5         50%         8.000000
# 6         75%         8.000000
# 7         max         8.000000}, 'SITUACION_LABORAL': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción SITUACION_LABORAL
# 0       count             23451
# 1      unique                 8
# 2         top   SIN INFORMACION
# 3        freq             12806}, 'ANHOSESTUDIO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  ANHOSESTUDIO
# 0       count   3860.000000
# 1        mean      9.768653
# 2         std      4.656437
# 3         min      0.000000
# 4         25%      6.000000
# 5         50%     11.000000
# 6         75%     12.000000
# 7         max     24.000000}, 'COD_ULT_CURSO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_ULT_CURSO
# 0       count   23465.000000
# 1        mean       7.898913
# 2         std       2.296065
# 3         min       1.000000
# 4         25%       9.000000
# 5         50%       9.000000
# 6         75%       9.000000
# 7         max       9.000000}, 'ULT_CURSO_APROBADO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción   ULT_CURSO_APROBADO
# 0       count                23465
# 1      unique                    8
# 2         top  No sabe/No responde
# 3        freq                18179}, 'CANCER_PREVIO1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CANCER_PREVIO1
# 0       count          23456
# 1      unique             45
# 2         top  Sin CA Previo
# 3        freq          22356}, 'FECHA1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHA1
# 0       count    778
# 1      unique     77
# 2         top   2007
# 3        freq     64}, 'CANCER_PREVIO2': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CANCER_PREVIO2
# 0       count          22066
# 1      unique             22
# 2         top  Sin CA Previo
# 3        freq          21713}, 'FECHA2': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHA2
# 0       count     55
# 1      unique     22
# 2         top   2009
# 3        freq      6}, 'PARENTESCO1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  PARENTESCO1
# 0       count        23495
# 1      unique           19
# 2         top  No registra
# 3        freq        17554}, 'CANCER_PARENTESCO1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CANCER_PARENTESCO1
# 0       count              22204
# 1      unique                 55
# 2         top      Sin CA Previo
# 3        freq              12712}, 'PARENTESCO2': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  PARENTESCO2
# 0       count        22166
# 1      unique           19
# 2         top  No registra
# 3        freq        14698}, 'CANCER_PARENTESCO2': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CANCER_PARENTESCO2
# 0       count              22101
# 1      unique                 43
# 2         top      Sin CA Previo
# 3        freq              14358}, 'PARENTESCO3': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  PARENTESCO3
# 0       count        22089
# 1      unique           19
# 2         top  No registra
# 3        freq        15247}, 'CANCER_PARENTESCO3': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CANCER_PARENTESCO3
# 0       count              22069
# 1      unique                 35
# 2         top      Sin CA Previo
# 3        freq              15098}, 'ID_COMITE': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ID_COMITE
# 0       count     23553
# 1      unique     18112
# 2         top       S/A
# 3        freq      4046}, 'DESCRIPCION_COMITE': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción DESCRIPCION_COMITE
# 0       count              23553
# 1      unique              14656
# 2         top                S/A
# 3        freq               4741}, 'FECHA_COMITE': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHA_COMITE
# 0       count        15498
# 1      unique         2913
# 2         top   22-08-2019
# 3        freq           28}, 'FEC_INGRESO_CASO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FEC_INGRESO_CASO
# 0       count            23547
# 1      unique             3686
# 2         top       12-08-2019
# 3        freq               24}, 'FEC_DIAGNO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  FEC_DIAGNO
# 0       count       23551
# 1      unique        3253
# 2         top  15-06-2021
# 3        freq          94}, 'INTERVALO_INGRESO_DIAGNO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  INTERVALO_INGRESO_DIAGNO
# 0       count              23547.000000
# 1        mean                 75.368327
# 2         std                270.999045
# 3         min              -6791.000000
# 4         25%                -18.000000
# 5         50%                  6.000000
# 6         75%                102.000000
# 7         max               4191.000000}, 'FEC_TOM_MUESTRA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FEC_TOM_MUESTRA
# 0       count           23548
# 1      unique            3225
# 2         top      15-06-2021
# 3        freq              94}, 'TIPO_TUMOR': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción TIPO_TUMOR
# 0       count      23546
# 1      unique          2
# 2         top     solido
# 3        freq      21074}, 'COD_TOPOLOGIA': {'Tipo': 'int64 (Numérica)', 'Resumen':   Descripción  COD_TOPOLOGIA
# 0       count   23553.000000
# 1        mean      46.303868
# 2         std      18.372297
# 3         min       1.000000
# 4         25%      34.000000
# 5         50%      50.000000
# 6         75%      61.000000
# 7         max      81.000000}, 'NOM_TOPOLOGIA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción NOM_TOPOLOGIA
# 0       count         23553
# 1      unique            69
# 2         top          Mama
# 3        freq          3500}, 'COD_DET_TOPOLOGIA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción COD_DET_TOPOLOGIA
# 0       count             23546
# 1      unique               278
# 2         top             C61.9
# 3        freq              3101}, 'NOM_DETALLE_TOPO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción     NOM_DETALLE_TOPO
# 0       count                23545
# 1      unique                  277
# 2         top  Glándula prostática
# 3        freq                 3101}, 'COD_CIE10': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción COD_CIE10
# 0       count     23548
# 1      unique       428
# 2         top     C61.X
# 3        freq      3173}, 'COD_MORFO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción     COD_MORFO
# 0       count  23549.000000
# 1        mean   8437.162979
# 2         std    535.454498
# 3         min   8000.000000
# 4         25%   8090.000000
# 5         50%   8211.000000
# 6         75%   8500.000000
# 7         max   9992.000000}, 'MORFO_COMPLETA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción              MORFO_COMPLETA
# 0       count                       23539
# 1      unique                         452
# 2         top  8140/3 ADENOCARCINOMA, SAI
# 3        freq                        4220}, 'COD_COMPORTAMIENTO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_COMPORTAMIENTO
# 0       count        23542.000000
# 1        mean            2.895039
# 2         std            0.413631
# 3         min            0.000000
# 4         25%            3.000000
# 5         50%            3.000000
# 6         75%            3.000000
# 7         max            3.000000}, 'NOM_COMPORTAMIENTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción NOM_COMPORTAMIENTO
# 0       count              23542
# 1      unique                  4
# 2         top            Maligno
# 3        freq              21714}, 'COD_EXTENSION': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_EXTENSION
# 0       count   23522.000000
# 1        mean       2.911530
# 2         std       3.138695
# 3         min       0.000000
# 4         25%       1.000000
# 5         50%       2.000000
# 6         75%       3.000000
# 7         max      10.000000}, 'EXTENSION_NOM': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción EXTENSION_NOM
# 0       count         23522
# 1      unique             6
# 2         top    Localizada
# 3        freq          9096}, 'COD_LATERALIDAD': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción  COD_LATERALIDAD
# 0       count     23514.000000
# 1        mean         3.393893
# 2         std         1.363125
# 3         min         1.000000
# 4         25%         2.000000
# 5         50%         4.000000
# 6         75%         4.000000
# 7         max         9.000000}, 'LATERALIDAD_NOM': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción LATERALIDAD_NOM
# 0       count           23514
# 1      unique               5
# 2         top  No Corresponde
# 3        freq           16388}, 'COD_GRADO': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción     COD_GRADO
# 0       count  23538.000000
# 1        mean      5.021880
# 2         std      3.287603
# 3         min      1.000000
# 4         25%      2.000000
# 5         50%      3.000000
# 6         75%      9.000000
# 7         max      9.000000}, 'GRADO_DIFERENCIACION': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción GRADO_DIFERENCIACION
# 0       count                23538
# 1      unique                    8
# 2         top          Desconocido
# 3        freq                 8885}, 'COD_BASE': {'Tipo': 'float64 (Numérica)', 'Resumen':   Descripción      COD_BASE
# 0       count  23547.000000
# 1        mean      6.465834
# 2         std      1.404227
# 3         min      1.000000
# 4         25%      7.000000
# 5         50%      7.000000
# 6         75%      7.000000
# 7         max      9.000000}, 'BASE_DIAGNOSTICA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción              BASE_DIAGNOSTICA
# 0       count                         23547
# 1      unique                             7
# 2         top  Histologia de Sitio Primario
# 3        freq                         19732}, 'TUMOR': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción     TUMOR
# 0       count     23553
# 1      unique         4
# 2         top  Primario
# 3        freq     21692}, 'GRAVEDAD': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción        GRAVEDAD
# 0       count           23553
# 1      unique               4
# 2         top  No Corresponde
# 3        freq           15748}, 'POBLACION': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  POBLACION
# 0       count      23553
# 1      unique          5
# 2         top  No Existe
# 3        freq      14136}, 'LINFOMA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción     LINFOMA
# 0       count         917
# 1      unique           2
# 2         top  No Hodgkin
# 3        freq         715}, 'FIGO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  FIGO
# 0       count  1867
# 1      unique     5
# 2         top     I
# 3        freq   674}, 'FIGO_LETRA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FIGO_LETRA
# 0       count       1431
# 1      unique          5
# 2         top          B
# 3        freq        950}, 'ETAPA_CLINICA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ETAPA_CLINICA
# 0       count         16550
# 1      unique             5
# 2         top            IV
# 3        freq          4700}, 'ETAPA_LETRA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ETAPA_LETRA
# 0       count        6004
# 1      unique           4
# 2         top           A
# 3        freq        2817}, 'TNM': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción    TNM
# 0       count  16664
# 1      unique   1035
# 2         top     |.
# 3        freq   1898}, 'SUBTIPO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción SUBTIPO
# 0       count   21489
# 1      unique       3
# 2         top       0
# 3        freq   20641}, 'RECEPTORES': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción           RECEPTORES
# 0       count                 4744
# 1      unique                 1470
# 2         top  |HER=No Corresponde
# 3        freq                 1034}, 'ESTADO_ACTUAL': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción        ESTADO_ACTUAL
# 0       count                23549
# 1      unique                    5
# 2         top  VIVO CON ENFERMEDAD
# 3        freq                12100}, 'ESTADO_ACTUAL_TTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ESTADO_ACTUAL_TTO
# 0       count             22610
# 1      unique                16
# 2         top              Alta
# 3        freq             12035}, 'ULTIMO_CONTACTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción ULTIMO_CONTACTO
# 0       count           23547
# 1      unique            3778
# 2         top      08-03-2022
# 3        freq             230}, 'FECHA_FALLECIMIENTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHA_FALLECIMIENTO
# 0       count                8325
# 1      unique                3296
# 2         top          23-06-2020
# 3        freq                  11}, 'CAUSAFALLECIMIENTO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción CAUSAFALLECIMIENTO
# 0       count               8251
# 1      unique                  2
# 2         top             Cancer
# 3        freq               7493}, 'ESTADO_RECH': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  ESTADO_RECH
# 0       count        23553
# 1      unique            5
# 2         top  FIN DE CASO
# 3        freq        20512}, 'CLASEDECASO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción                               CLASEDECASO
# 0       count                                     23551
# 1      unique                                         7
# 2         top  Diagnosticado en recinto, TTO en recinto
# 3        freq                                     11153}, 'FUENTE1': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción       FUENTE1
# 0       count         20933
# 1      unique            10
# 2         top  RADIOTERAPIA
# 3        freq          5312}, 'FUENTE2': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción  FUENTE2
# 0       count     7533
# 1      unique       10
# 2         top  COMITES
# 3        freq     1628}, 'FUENTE3': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FUENTE3
# 0       count    1763
# 1      unique      10
# 2         top     CAE
# 3        freq     414}, 'ESTADO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción       ESTADO
# 0       count        23553
# 1      unique            5
# 2         top  CORRESPONDE
# 3        freq        23354}, 'INTENCION_TRATA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción INTENCION_TRATA
# 0       count           21800
# 1      unique               2
# 2         top        Curativo
# 3        freq           15407}, 'RESPUESTA_TRATA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción     RESPUESTA_TRATA
# 0       count               21782
# 1      unique                   7
# 2         top  Enfermedad Estable
# 3        freq               12867}, 'TIPOTERAPIA': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción   TIPOTERAPIA
# 0       count         23553
# 1      unique           999
# 2         top  |Teleterapia
# 3        freq          5478}, 'FECHAINICIO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHAINICIO
# 0       count       23553
# 1      unique       10025
# 2         top           |
# 3        freq        1202}, 'FECHATERMINO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción FECHATERMINO
# 0       count        23553
# 1      unique        10352
# 2         top            |
# 3        freq         1608}, 'TIPO': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción   TIPO
# 0       count  23553
# 1      unique    326
# 2         top     |-
# 3        freq   7006}, 'OBSERVACIONES': {'Tipo': 'object (Categórica)', 'Resumen':   Descripción OBSERVACIONES
# 0       count         22543
# 1      unique         15588
# 2         top             |
# 3        freq          2613}}

# %%
# 2. Obtener información sobre las columnas
diccionario_columnas_numericas = {}
diccionario_columnas_categoricas = {}

for columna in df.columns:
    tipo_variable = str(df[columna].dtype)  # Convertir a cadena de texto
    
    # Resumen del contenido
    if pd.api.types.is_datetime64_any_dtype(df[columna]):
        resumen_contenido = df[columna].describe(datetime_is_numeric=True).reset_index().rename(columns={'index': 'Descripción'})
    else:
        resumen_contenido = df[columna].describe().reset_index().rename(columns={'index': 'Descripción'})
    
    # Agregar información sobre si la variable es numérica o categórica
    if pd.api.types.is_numeric_dtype(df[columna]):
        tipo_variable += " (Numérica)"
        # Agregar al diccionario de columnas numéricas
        diccionario_columnas_numericas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }
    else:
        tipo_variable += " (Categórica)"
        # Agregar al diccionario de columnas categóricas
        diccionario_columnas_categoricas[columna] = {
            "Tipo": tipo_variable,
            "Resumen": resumen_contenido
        }

# 3. Exportar el diccionario a Excel
ruta_excel = "../docs/Diccionario_Original_DS_Cancer.xlsx"   # Ruta donde se guardará el archivo Excel
with pd.ExcelWriter(ruta_excel) as writer:
    # Hoja para columnas numéricas
    df_numericas = pd.DataFrame()
    for columna, info in diccionario_columnas_numericas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_numericas = pd.concat([df_numericas, resumen_transpuesto], ignore_index=True)
    df_numericas.to_excel(writer, index=False, sheet_name="Columnas Numéricas")
    
    # Hoja para columnas categóricas
    df_categoricas = pd.DataFrame()
    for columna, info in diccionario_columnas_categoricas.items():
        resumen_transpuesto = info['Resumen'].T.reset_index()
        resumen_transpuesto['Columna'] = columna
        resumen_transpuesto = resumen_transpuesto.rename(columns={0: 'Descripción', columna: 'Valor'})
        df_categoricas = pd.concat([df_categoricas, resumen_transpuesto], ignore_index=True)
    df_categoricas.to_excel(writer, index=False, sheet_name="Columnas Categóricas")

print("El diccionario de columnas se ha exportado a Excel exitosamente.")
# Out:
# El diccionario de columnas se ha exportado a Excel exitosamente.
